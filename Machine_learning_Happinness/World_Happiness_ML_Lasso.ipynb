# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler  #Standardisation
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_absolute_error, mean_squared_error
import matplotlib.pyplot as plt
import scipy.stats as stats
import seaborn as sns
from sklearn.model_selection import learning_curve

from sklearn.linear_model import Lasso

# %%
#Importer le fichier

df = pd.read_csv("/Users/bapt/Library/Mobile Documents/com~apple~CloudDocs/DataAnalyst:Scientist/DataScientest_cours/Projet_fil_rouge_Hapiness/World_happiness_ML.csv",
                index_col = "Unnamed: 0")
df.head()
# Out:
#    Ladder_score  PIB_habitant  Social_support  Healthy_life_expectancy  \
# 0         3.724         7.370           0.451                    50.80
# 1         4.402         7.540           0.552                    51.20
# 2         4.758         7.647           0.539                    51.60
# 3         3.832         7.620           0.521                    51.92
# 4         3.783         7.705           0.521                    52.24
#
#    Freedom  Generosity  Corruption  Positive_affect  Negative_affect  \
# 0    0.718       0.168       0.882            0.518            0.258
# 1    0.679       0.190       0.850            0.584            0.237
# 2    0.600       0.121       0.707            0.618            0.275
# 3    0.496       0.162       0.731            0.611            0.267
# 4    0.531       0.236       0.776            0.710            0.268
#
#    Region_Central and Eastern Europe  \
# 0                              False
# 1                              False
# 2                              False
# 3                              False
# 4                              False
#
#    Region_Commonwealth of Independent States  Region_East Asia  \
# 0                                      False             False
# 1                                      False             False
# 2                                      False             False
# 3                                      False             False
# 4                                      False             False
#
#    Region_Latin America and Caribbean  Region_Middle East and North Africa  \
# 0                               False                                False
# 1                               False                                False
# 2                               False                                False
# 3                               False                                False
# 4                               False                                False
#
#    Region_North America and ANZ  Region_South Asia  Region_Southeast Asia  \
# 0                         False               True                  False
# 1                         False               True                  False
# 2                         False               True                  False
# 3                         False               True                  False
# 4                         False               True                  False
#
#    Region_Sub-Saharan Africa  Region_Western Europe
# 0                      False                  False
# 1                      False                  False
# 2                      False                  False
# 3                      False                  False
# 4                      False                  False

# %%
#Valeurs manquantes

df.isna().sum()
# Out:
# Ladder_score                                 0
# PIB_habitant                                 0
# Social_support                               0
# Healthy_life_expectancy                      0
# Freedom                                      0
# Generosity                                   0
# Corruption                                   0
# Positive_affect                              0
# Negative_affect                              0
# Region_Central and Eastern Europe            0
# Region_Commonwealth of Independent States    0
# Region_East Asia                             0
# Region_Latin America and Caribbean           0
# Region_Middle East and North Africa          0
# Region_North America and ANZ                 0
# Region_South Asia                            0
# Region_Southeast Asia                        0
# Region_Sub-Saharan Africa                    0
# Region_Western Europe                        0
# dtype: int64

# %%
#Séparer les jeux de données en un groupe train et un test

feats = df.drop("Ladder_score", axis = 1)  #Mettre dans X les variables explicatives
target = df["Ladder_score"]  #Mettre dans y la variable cible

#Faire un groupe train et un test
X_train, X_test, y_train, y_test = train_test_split(feats, target, test_size = 0.25, random_state = 42)

# %%
#Normalisation des données

#sc = StandardScaler()

#X_train = sc.fit_transform(X_train)
#X_test = sc.fit_transform(X_test)

# %%
#Groupement et instanciation modele

lasso_reg = Lasso(alpha = 0.1)
lasso_reg.fit(X_train, y_train)
# Out:
# Lasso(alpha=0.1)

# %%
# Définir les paramètres à optimiser
param_grid = {
    'alpha': np.arange(0.01, 10.0, 0.05)
}

# Créer l'objet GridSearchCV
grid_search = GridSearchCV(estimator=lasso_reg, param_grid=param_grid, scoring='neg_mean_squared_error', cv=5)

# Effectuer la recherche par grille sur les données d'entraînement
grid_search.fit(X_train, y_train)

# Afficher les meilleurs paramètres
print("Meilleurs paramètres:", grid_search.best_params_)

# Obtenir le meilleur modèle
best_lasso_reg = grid_search.best_estimator_

# Prédire sur les données de test avec le meilleur modèle
y_pred = best_lasso_reg.predict(X_test)


#Quantifier l'erreur du modèle
print('Coefficient de détermination du modèle sur train:', best_lasso_reg.score(X_train, y_train))
print('Coefficient de détermination du modèle sur test:', best_lasso_reg.score(X_test, y_test))

mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test, y_pred)

print("mse :", mse)
print("rmse :", rmse)
print("mae :", mae)
# Out:
# Meilleurs paramètres: {'alpha': 0.01}
# Coefficient de détermination du modèle sur train: 0.7618961583503037
# Coefficient de détermination du modèle sur test: 0.7768181069467532
# mse : 0.26751307106045547
# rmse : 0.5172166577561627
# mae : 0.40967809067941185

# %%
# Créer une DataFrame avec les noms des variables
coefficients_df = pd.DataFrame({
    "Variable": feats.columns,  # Noms des variables
    "Coefficient": best_lasso_reg.coef_  # Coefficients associés
})

residuals = y_test - y_pred

plt.figure(figsize = (12,4))
plt.subplot(121)

# Tracer le nuage de points des résidus avec la droite de régression
plt.scatter(y_test, residuals, label='Résidus', c ="blue")
plt.axhline(y=0, color='r', linestyle='--', label='Droite y=0')
plt.title("Nuage de points des résidus avec droite de régression \n pour le modèle Lasso")
plt.xlabel("Valeurs réelles")
plt.ylabel("Résidus (Valeurs réelles - Prédictions)")
plt.legend()

#Afficher le QQplot
plt.subplot(122)
stats.probplot(residuals, dist="norm", plot=plt)
plt.title("QQ-Plot des Résidus \n pour le modèle Lasso")
plt.show()



#Afficher les features importance et ses coefficients

coefficients_df_sorted = coefficients_df.sort_values(by = "Coefficient", ascending = False).reset_index()
coefficients_df_sorted.drop("index", axis = 1, inplace = True)

sns.barplot(y = coefficients_df_sorted["Variable"], x = coefficients_df_sorted["Coefficient"], 
            data = coefficients_df_sorted, palette = "viridis")
plt.title("Histogramme des features importance \n pour le modèle Lasso")
plt.show()

display(coefficients_df_sorted)
# Out:
#                                      Variable  Coefficient
# 0                                     Freedom     0.587212
# 1                             Positive_affect     0.545985
# 2                              Social_support     0.534708
# 3                                PIB_habitant     0.520518
# 4          Region_Latin America and Caribbean     0.470789
# 5                                  Generosity     0.449584
# 6                       Region_Western Europe     0.301899
# 7                Region_North America and ANZ     0.273147
# 8                     Healthy_life_expectancy     0.017676
# 9                             Negative_affect    -0.000000
# 10          Region_Central and Eastern Europe    -0.000000
# 11        Region_Middle East and North Africa    -0.000000
# 12                          Region_South Asia    -0.000000
# 13                      Region_Southeast Asia    -0.000000
# 14                  Region_Sub-Saharan Africa    -0.000000
# 15  Region_Commonwealth of Independent States     0.000000
# 16                           Region_East Asia    -0.044894
# 17                                 Corruption    -0.275173

# %%
#Afficher la courbe d'apprentissage

# Augmenter la taille de l'ensemble d'entraînement
increased_size = int(3 * len(X_train))
    
train_sizes, train_scores, test_scores = learning_curve(
        best_lasso_reg, X_train[:increased_size], y_train[:increased_size], cv=5, scoring='r2'
    )

train_scores_mean = np.mean(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)

plt.figure(figsize=(8, 4))
plt.plot(train_sizes, train_scores_mean, label='R² Entraînement')
plt.plot(train_sizes, test_scores_mean, label='R² Validation')
plt.xlabel('Taille de l\'ensemble d\'entraînement')
plt.ylabel('R²')
plt.title('Courbe d\'apprentissage')
plt.legend()
plt.show()
